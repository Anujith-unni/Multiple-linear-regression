# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
data = pd.read_csv("bnkloan.csv")

# %%
data
# Out:
#       age  ed  employ  address  income  debtinc  creddebt  othdebt  default  \
# 0      28   2       7        2      44     17.7     2.991        5        0
# 1      64   5      34       17     116     14.7     5.047       12        0
# 2      40   1      20       12      61      4.8     1.042        2        0
# 3      30   1      11        3      27     34.5     1.751        8        0
# 4      25   1       2        2      30     22.4     0.759        6        1
# ...   ...  ..     ...      ...     ...      ...       ...      ...      ...
# 1495   34   3       8        4      83     11.0     1.853        7        0
# 1496   37   2      10        8      43      3.6     0.807        1        0
# 1497   25   5       0        3      16      3.2     0.288        0        0
# 1498   34   1      10        8      41     14.5     1.195        5        0
# 1499   27   1       2        2      24      5.8     0.555        1        0
#
#        debt  cred  otherdebt       in
# ...

# %%
#multiple regression
reg=linear_model.LinearRegression()
reg.fit(data[['age','debt','cred']],data[['in']])
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([[15325.43260924,   -28.17849749,   126.69242348]])

# %%
reg.intercept_
# Out:
# array([106808.4784611])
